# %% [markdown]
# # Import des modules

# %%
from scipy.misc import imread
from sklearn.externals import joblib

import random as rand
import numpy as np 
import cv2
import glob
import time

import matplotlib.pyplot as plt
# %matplotlib inline

from helpers import convert, show_images
from featuresourcer import FeatureSourcer
from binaryclassifier import BinaryClassifier

# %% [markdown]
# # Telechargement du modele sauvegardé et configuration des parametres HOG

# %%
svc = joblib.load('svc_olive087.pkl')
scaler = joblib.load('scaler_olive087.pkl')
classifier = BinaryClassifier(svc, scaler)

sourcer_params = {
  'color_model': 'yuv',                # hls, hsv, yuv, ycrcb
  'bounding_box_size': 64,             #
  'number_of_orientations': 11,        # 6 - 12
  'pixels_per_cell': 16,               # 8, 16
  'cells_per_block': 2,                # 1, 2
  'do_transform_sqrt': True
}

# %% [markdown]
# # Lecture des images de test

# %%
new_frame1 = cv2.resize(imread("test_olive/1.jpg"),(400,600)) #1
print(" images shape: ", new_frame1.shape)
new_frame2 = cv2.resize(imread("test_olive/2.jpg"),(400,600)) #1
new_frame3 = cv2.resize(imread("test_olive/3.jpg"),(400,600))    #1
new_frame4 = cv2.resize(imread("test_olive/4.jpg"),(400,600))    #1
new_frame5 = cv2.resize(imread("test_olive/5.jpg"),(400,600))     #1
new_frame6 = cv2.resize(imread("test_olive/6.jpg"),(400,600))     #1
new_frame7 = cv2.resize(imread("test_olive/7.jpg"),(400,600))     #1
new_frame8 = cv2.resize(imread("test_olive/8.jpg"),(400,600))     #1
new_frame9 = cv2.resize(imread("test_olive/9.jpg"),(400,600))     #1
new_frame10 = cv2.resize(imread("test_olive/10.jpg"),(400,600))     #1
new_frame11 = cv2.resize(imread("test_olive/11.jpg"),(400,600))     #1
new_frame12 = cv2.resize(imread("test_olive/12.jpg"),(400,600))     #1
new_frame13 = cv2.resize(imread("test_olive/13.jpg"),(400,600))     #1
# Out:
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# ...

# %%
new_frame1 = cv2.resize(imread("test_olive/1.jpg"),(400,600)) #1
print("images shape: ", new_frame1.shape)
new_frame2 = cv2.resize(imread("test_olive/1.jpg"),(400,600)) #0
new_frame3 = cv2.resize(imread("test_olive/1.jpg"),(400,600))    #1
new_frame4 = cv2.resize(imread("test_olive/1.jpg"),(400,600))    #0
new_frame5 = cv2.resize(imread("test/pomme2.jpg"),(400,600))     #1
new_frame6 = cv2.resize(imread("test/no2.jpg"),(400,600))     #0
new_frame7 = cv2.resize(imread("test/pomme3.jpg"),(400,600))     #1
new_frame8 = cv2.resize(imread("test/no3.jpg"),(400,600))     #0
new_frame9 = cv2.resize(imread("test/pomme4.jpg"),(400,600))     #1
new_frame10 = cv2.resize(imread("test/no4.jpg"),(400,600))     #0
new_frame11 = cv2.resize(imread("test/pomme5.jpg"),(400,600))     #1
new_frame12 = cv2.resize(imread("test/no5.jpg"),(400,600))     #0
new_frame13 = cv2.resize(imread("test/pomme6.jpg"),(400,600))     #1
new_frame14 = cv2.resize(imread("test/no6.jpg"),(400,600))     #0
new_frame15 = cv2.resize(imread("test/pomme7.jpg"),(400,600))     #1
new_frame16 = cv2.resize(imread("test/pomme8.jpg"),(400,600))     #1
# Out:
# images shape:  (600, 400, 3)
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# ...

# %% [markdown]
# # Affichage des resultats de test: 1 si reconnu 0 sinon

# %%
src = FeatureSourcer(sourcer_params, new_frame1)

# %%
src = FeatureSourcer(sourcer_params, new_frame1)
#src.slice(0, 0, 64, 64) = beantown.target
#y = src.slice(0, 0, 64, 64).reshape(src.slice(0, 0, 64, 2).size, 1)

src.new_frame(new_frame1)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame2)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame3)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame4)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")
# Out:
# 1111

# %%
src.slice(0, 0, 64, 64).shape
# Out:
# (1188,)

# %%
new_frame5 = cv2.resize(imread("test_olive/asc.jpg"),(400,600))     #1
# Out:
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
src.new_frame(new_frame5)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")
# Out:
# 1

# %%
src.new_frame(new_frame5)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame6)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame7)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame8)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame9)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame10)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame11)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame12)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame13)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")
# Out:
# 101011001

# %%
src.new_frame(new_frame14)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")


src.new_frame(new_frame15)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame16)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")
# Out:
# 000

# %%
new_frame11 = cv2.resize(imread("pt_test/0001.jpg"),(400,600)) #1
print("images shape: ", new_frame1.shape)
new_frame21 = cv2.resize(imread("pt_test/0001.jpg"),(400,600)) #0
new_frame31 = cv2.resize(imread("pt_test/00015.jpg"),(400,600))    #1
new_frame41 = cv2.resize(imread("pt_test/00019.jpg"),(400,600))    #0
new_frame51 = cv2.resize(imread("pt_test/00023.jpg"),(400,600))     #1
new_frame61 = cv2.resize(imread("pt_test/00026.jpg"),(400,600))     #0
new_frame71 = cv2.resize(imread("pt_test/00032.jpg"),(400,600))     #1
new_frame81 = cv2.resize(imread("pt_test/00045.jpg"),(400,600))     #0
new_frame91 = cv2.resize(imread("pt_test/00047.jpg"),(400,600))     #1
new_frame101 = cv2.resize(imread("pt_test/00053.jpg"),(400,600))     #0
new_frame111 = cv2.resize(imread("pt_test/00054.jpg"),(400,600))     #1
new_frame121 = cv2.resize(imread("pt_test/00055.jpg"),(400,600))     #0
# Out:
# images shape:  (600, 400, 3)
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# ...

# %%
src.new_frame(new_frame11)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame21)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame31)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame41)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame51)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame61)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame71)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame81)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame91)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame101)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame111)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame121)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "\n")
# Out:
# 000010110111

# %%
print(src.slice(0, 0, 400, 600))
# Out:
# [0.36843143 0.07929583 0.06528135 ... 0.02590557 0.04247359 0.01000423]

# %%
print(type(src.slice(0, 0, 400, 600)))
# Out:
# <class 'numpy.ndarray'>

# %%
new_frame33 = cv2.resize(imread("pt_test/0001.jpg"),(400,600)) #1
print("Vehicle images shape: ", new_frame1.shape)
new_frame34 = cv2.resize(imread("test_pos/pomme1.jpg"),(400,600)) #0
new_frame35 = cv2.resize(imread("test_pos/pomme2.jpg"),(400,600))    #1
new_frame36 = cv2.resize(imread("test_pos/pomme3.jpg"),(400,600))    #0
new_frame37 = cv2.resize(imread("test_pos/pomme4.jpg"),(400,600))     #1
new_frame38 = cv2.resize(imread("test_pos/pomme5.jpg"),(400,600))     #0
new_frame39 = cv2.resize(imread("test_pos/pomme6.jpg"),(400,600))     #1
new_frame40 = cv2.resize(imread("test_pos/pomme7.jpg"),(400,600))     #0
# Out:
# Vehicle images shape:  (600, 400, 3)
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# ...

# %%
src.new_frame(new_frame33)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame34)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame35)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame36)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame37)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame38)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame39)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame40)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")
# Out:
# 01011010

# %%
new_frame56 = cv2.resize(imread("test_neg/no1.jpg"),(400,600)) #0
new_frame57 = cv2.resize(imread("test_neg/no2.jpg"),(400,600))    #1
new_frame58 = cv2.resize(imread("test_neg/no3.jpg"),(400,600))    #0
new_frame59 = cv2.resize(imread("test_neg/no4.jpg"),(400,600))     #1
new_frame60 = cv2.resize(imread("test_neg/no5.jpg"),(400,600))     #0
new_frame61 = cv2.resize(imread("test_neg/no6.jpg"),(400,600))     #1
# Out:
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# ...

# %%
src.new_frame(new_frame56)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame57)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame58)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame59)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame60)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")

src.new_frame(new_frame61)
print(classifier.predict(src.slice(0, 0, 400, 600)), end = "")
# Out:
# 000100

# %%
def olive_Classifier(path):
    img = cv2.imread(path)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    out = cv2.resize(imread(path),(400,600))
    src.new_frame(out)
    if classifier.predict(src.slice(0, 0, 400, 600)) == 1 :
        print("- Olive")

# %%
olive_Classifier("test_pos/pomme1.jpg")
# Out:
# C:\Users\MALIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# - Olive
